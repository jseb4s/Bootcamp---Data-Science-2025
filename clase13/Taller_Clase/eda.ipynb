# %% [markdown]
# ### ***Amazon Sales Dataset***
# ### ***Dataset:*** [link](https://www.kaggle.com/datasets/karkavelrajaj/amazon-sales-dataset)
#
# ## ***Variables***
#
# - product_id - Product ID
# - product_name - Name of the Product
# - category - Category of the Product
# - discounted_price - Discounted Price of the Product
# - actual_price - Actual Price of the Product
# - discount_percentage - Percentage of Discount for the Product
# - rating - Rating of the Product
# - rating_count - Number of people who voted for the Amazon rating
# - about_product - Description about the Product
# - user_id - ID of the user who wrote review for the Product
# - user_name - Name of the user who wrote review for the Product
# - review_id - ID of the user review
# - review_title - Short review
# - review_content - Long review
# - img_link - Image Link of the Product
# - product_link - Official Website Link of the Product

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\JUANC\Documents\Machine Learning\bit\Bootcamp DS\clase13\Taller_Clase\amazon.csv")

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
df.shape
# Out:
# (1465, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %% [markdown]
# - Nuestro df tiene 1465 registros, 16 columnas.
# - Rating count tiene 2 valores nulos.

# %%
df['discounted_price'] = df["discounted_price"].str.replace("₹", '')
df['discounted_price'] = df["discounted_price"].str.replace(",", '')
df['discounted_price'] = df["discounted_price"].astype('float64')

# %%
df['actual_price'] = df["actual_price"].str.replace("₹", '')
df['actual_price'] = df["actual_price"].str.replace(",", '')
df['actual_price'] = df["actual_price"].astype('float64')

# %%
df['discount_percentage'] = df["discount_percentage"].str.replace("%", '').astype('float64')

# %%
df['discount_percentage'] = df['discount_percentage']/100

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage rating rating_count  \
# 0        1099.0                 0.64    4.2       24,269
# ...

# %%
df['rating'].value_counts()
# Out:
# rating
# 4.1    244
# 4.3    230
# 4.2    228
# 4.0    129
# 3.9    123
# 4.4    123
# 3.8     86
# 4.5     75
# 4       52
# 3.7     42
# 3.6     35
# 3.5     26
# 4.6     17
# 3.3     16
# 3.4     10
# 4.7      6
# 3.1      4
# 5.0      3
# 3.0      3
# 4.8      3
# 3.2      2
# 2.8      2
# 2.3      1
# |        1
# 2        1
# 3        1
# 2.6      1
# 2.9      1
# Name: count, dtype: int64

# %%
df.query('rating == "|"')
# Out:
#       product_id                                       product_name  \
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#                                                category  discounted_price  \
# 1279  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...            2099.0
#
#       actual_price  discount_percentage rating rating_count  \
# 1279        2499.0                 0.16      |          992
#
#                                           about_product  \
# 1279  No Installation is provided for this product|1...
#
#                                                 user_id  \
# 1279  AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
#
#                                               user_name  \
# 1279  Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
#
#                                               review_id  \
# 1279  R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
#
#                                            review_title  \
# ...

# %%
df['rating'] = df['rating'].str.replace('|', '2.5').astype('float64')

# %%
df['rating_count'] = df['rating_count'].str.replace(',', '').astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   float64
#  7   rating_count         1463 non-null   float64
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
df.describe()
# Out:
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1465.000000    1465.000000          1465.000000  1465.000000
# mean        3125.310874    5444.990635             0.476915     4.095495
# std         6944.304394   10874.826864             0.216359     0.294543
# min           39.000000      39.000000             0.000000     2.000000
# 25%          325.000000     800.000000             0.320000     4.000000
# 50%          799.000000    1650.000000             0.500000     4.100000
# 75%         1999.000000    4295.000000             0.630000     4.300000
# max        77990.000000  139900.000000             0.940000     5.000000
#
#         rating_count
# count    1463.000000
# mean    18295.541353
# std     42753.864952
# min         2.000000
# 25%      1186.000000
# 50%      5179.000000
# 75%     17336.500000
# max    426973.000000

# %% [markdown]
# - El promedio de descuento es $3125...

# %%
df["rating_count"] = df.rating_count.fillna(value = df['rating_count'].median())

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df.duplicated().any()
# Out:
# False

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#import plotly.express as

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                 0.64     4.2       24269.0
# ...

# %%
plt.scatter(df['actual_price'], df['rating'])
plt.show()

# %%
import plotly.express as px

fig = px.scatter(df, x = 'actual_price', y = 'rating')
fig.show()

# %%
fig = px.scatter(df, x = 'actual_price', y = 'discount_percentage')
fig.show()

# %%
fig = px.scatter(df, x = 'discount_percentage', y = 'rating')
fig.show()

# %%
fig = px.density_heatmap(df, x = 'discount_percentage', y = 'rating', color_continuous_scale="Viridis")
fig.show()

# %%
corr_matrix = df.corr(numeric_only=True)

sns.heatmap(corr_matrix, annot = True, cmap="coolwarm", center = 0)
plt.show()

# %%
fig = px.box(df, x = 'actual_price')
fig.show()

# %%
plt.hist(df['discount_percentage'])
plt.show()

# %%
fig = px.histogram(df, x = 'actual_price', nbins=50)
fig.show()

# %%
fig = px.box(df, x = 'actual_price')
fig.show()

# %%
tabla_top5 = df.groupby('category', as_index=False)['actual_price'].sum()
tabla_top5 = tabla_top5.sort_values(by = 'actual_price', ascending=False).head(5)

# %%
tabla_top5
# Out:
#                                               category  actual_price
# 97   Electronics|HomeTheater,TV&Video|Televisions|S...    2528369.00
# 117  Electronics|Mobiles&Accessories|Smartphones&Ba...    1400351.00
# 119        Electronics|WearableTechnology|SmartWatches     650162.00
# 10   Computers&Accessories|Accessories&Peripherals|...     211103.32
# 191  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...     187426.00

# %%
plt.figure(figsize=(10,6))
plt.barh(tabla_top5['category'], tabla_top5['actual_price'])
plt.show()

# %%
Q1 = df['actual_price'].quantile(0.25)
Q3 = df['actual_price'].quantile(0.75)
IQR = Q3-Q1

df_2 = df[df['actual_price'] > Q3+IQR]
df_2
# Out:
#       product_id                                       product_name  \
# 16    B0B6F7LX4C  MI 80 cm (32 inches) 5A Series HD Ready Smart ...
# 19    B08DPLCM6T  LG 80 cm (32 inches) HD Ready Smart LED TV 32L...
# 22    B09F6S8BT6  Samsung 80 cm (32 Inches) Wondertainment Serie...
# 24    B0B1YVCJ2Y  Acer 80 cm (32 inches) I Series HD Ready Andro...
# 26    B08B42LWKN  OnePlus 80 cm (32 inches) Y Series HD Ready LE...
# ...          ...                                                ...
# 1428  B078JT7LTD  Sujata Dynamix, Mixer Grinder, 900 Watts, 3 Ja...
# 1430  B092R48XXB  Mi Robot Vacuum-Mop P, Best-in-class Laser Nav...
# 1432  B0977CGNJJ  AGARO Royal Stand 1000W Mixer with 5L SS Bowl ...
# 1437  B00JBNZPFM  Karcher WD3 EU Wet and Dry Vacuum Cleaner, 100...
# 1438  B08N6P8G5K  INALSA Air Fryer Digital 4L Nutri Fry - 1400W ...
#
#                                                category  discounted_price  \
# 16    Electronics|HomeTheater,TV&Video|Televisions|S...           13999.0
# ...

# %%
tabla_outliers = df_2.groupby('category', as_index=False)['actual_price'].sum()
tabla_outliers
# Out:
#                                              category  actual_price
# 0   Computers&Accessories|ExternalDevices&DataStor...        7999.0
# 1   Computers&Accessories|ExternalDevices&DataStor...       32000.0
# 2    Computers&Accessories|Laptops|TraditionalLaptops       59890.0
# 3                      Computers&Accessories|Monitors       32860.0
# 4   Computers&Accessories|Printers,Inks&Accessorie...        9625.0
# 5                       Computers&Accessories|Tablets       37999.0
# 6   Electronics|Headphones,Earbuds&Accessories|Hea...       42987.0
# 7     Electronics|HomeAudio|Speakers|SoundbarSpeakers       12499.0
# 8         Electronics|HomeTheater,TV&Video|Projectors       54880.0
# 9   Electronics|HomeTheater,TV&Video|Televisions|S...     2528369.0
# 10  Electronics|HomeTheater,TV&Video|Televisions|S...       91978.0
# 11  Electronics|Mobiles&Accessories|Smartphones&Ba...     1400351.0
# 12        Electronics|WearableTechnology|SmartWatches      468360.0
# ...

# %%
tabla_outliers = tabla_outliers.sort_values(by = 'actual_price', ascending=False)

# %%
tabla_outliers
# Out:
#                                              category  actual_price
# 9   Electronics|HomeTheater,TV&Video|Televisions|S...     2528369.0
# 11  Electronics|Mobiles&Accessories|Smartphones&Ba...     1400351.0
# 12        Electronics|WearableTechnology|SmartWatches      468360.0
# 33  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...      182877.0
# 18  Home&Kitchen|Heating,Cooling&AirQuality|WaterH...      134559.0
# 14  Home&Kitchen|Heating,Cooling&AirQuality|AirPur...      108453.0
# 10  Electronics|HomeTheater,TV&Video|Televisions|S...       91978.0
# 31  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...       89899.0
# 13  Home&Kitchen|Heating,Cooling&AirQuality|AirCon...       75990.0
# 20  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...       60584.0
# 2    Computers&Accessories|Laptops|TraditionalLaptops       59890.0
# 8         Electronics|HomeTheater,TV&Video|Projectors       54880.0
# 32  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...       53142.0
# ...
